# %%
# library import
import pandas as pd
import numpy as np
import random as rnd

# %%
df=pd.read_csv("D:/Prateek/Intersnship_Data/INSAID Internship/Fraud_1.csv")
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
#Getting knowledge of columns datatype

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
#getting knowledge of dataset

df.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# ...

# %%
#finding  any null value in  dataset

df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %% [markdown]
# as we got to know that there is no null value in dataset

# %%
# data of fraud dectected
df[df["isFraud"]==1]
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 251         1  TRANSFER     2806.00  C1420196421        2806.00
# 252         1  CASH_OUT     2806.00  C2101527076        2806.00
# 680         1  TRANSFER    20128.00   C137533655       20128.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 2                   0.0   C553264065            0.00            0.00        1
# ...

# %%
df["isFlaggedFraud"].sum()
# Out:
# 16

# %%
# data of  isFlaggedFraud and isFraud
df[(df.isFlaggedFraud==1) & (df.isFraud==1 )]
# Out:
#          step      type       amount     nameOrig  oldbalanceOrg  \
# 2736446   212  TRANSFER   4953893.08   C728984460     4953893.08
# 3247297   250  TRANSFER   1343002.08  C1100582606     1343002.08
# 3760288   279  TRANSFER    536624.41  C1035541766      536624.41
# 5563713   387  TRANSFER   4892193.09   C908544136     4892193.09
# 5996407   425  TRANSFER  10000000.00   C689608084    19585040.37
# 5996409   425  TRANSFER   9585040.37   C452586515    19585040.37
# 6168499   554  TRANSFER   3576297.10   C193696150     3576297.10
# 6205439   586  TRANSFER    353874.22  C1684585475      353874.22
# 6266413   617  TRANSFER   2542664.27   C786455622     2542664.27
# 6281482   646  TRANSFER  10000000.00    C19004745    10399045.08
# 6281484   646  TRANSFER    399045.08   C724693370    10399045.08
# 6296014   671  TRANSFER   3441041.46   C917414431     3441041.46
# 6351225   702  TRANSFER   3171085.59  C1892216157     3171085.59
# ...

# %%
df[(df.isFlaggedFraud==1) & (df.isFraud==1 )].shape
# Out:
# (16, 11)

# %%
# unique items in type
df["type"].unique()
# Out:
# array(['PAYMENT', 'TRANSFER', 'CASH_OUT', 'DEBIT', 'CASH_IN'],
#       dtype=object)

# %%
# now we covert text data into numerical data by using label encoder



from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
df["type"] = enc.fit_transform(df.type)
df['nameOrig'] = enc.fit_transform(df['nameOrig'])
df['nameDest'] = enc.fit_transform(df['nameDest'])

# %%
df
# Out:
#          step  type      amount  nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1     3     9839.64    757869      170136.00       160296.36
# 1           1     3     1864.28   2188998       21249.00        19384.72
# 2           1     4      181.00   1002156         181.00            0.00
# 3           1     1      181.00   5828262         181.00            0.00
# 4           1     3    11668.14   3445981       41554.00        29885.86
# ...       ...   ...         ...       ...            ...             ...
# 6362615   743     1   339682.13   5651847      339682.13            0.00
# 6362616   743     4  6311409.28   1737278     6311409.28            0.00
# 6362617   743     1  6311409.28    533958     6311409.28            0.00
# 6362618   743     4   850002.52   2252932      850002.52            0.00
# 6362619   743     1   850002.52    919229      850002.52            0.00
#
#          nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# ...

# %%
#  correlation of colunms with each other
df.corr()
# Out:
#                     step      type    amount  nameOrig  oldbalanceOrg  \
# step            1.000000  0.006635  0.022373 -0.000146      -0.010058
# type            0.006635  1.000000  0.088419  0.000213      -0.339760
# amount          0.022373  0.088419  1.000000  0.000124      -0.002762
# nameOrig       -0.000146  0.000213  0.000124  1.000000      -0.000648
# oldbalanceOrg  -0.010058 -0.339760 -0.002762 -0.000648       1.000000
# newbalanceOrig -0.010299 -0.352758 -0.007861 -0.000675       0.998803
# nameDest        0.003767  0.584275 -0.169150 -0.000256      -0.162688
# oldbalanceDest  0.027665 -0.104679  0.294137  0.000245       0.066243
# newbalanceDest  0.025888 -0.059364  0.459304  0.000255       0.042029
# isFraud         0.031578  0.020833  0.076688 -0.000464       0.010154
# isFlaggedFraud  0.003277  0.002685  0.012295  0.000667       0.003835
#
#                 newbalanceOrig  nameDest  oldbalanceDest  newbalanceDest  \
# ...

# %%
#drop the target data from colunm and copy to other variable

X = df.drop(['isFraud'], axis = 1)
y = df['isFraud']

# %%
X
# Out:
#          step  type      amount  nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1     3     9839.64    757869      170136.00       160296.36
# 1           1     3     1864.28   2188998       21249.00        19384.72
# 2           1     4      181.00   1002156         181.00            0.00
# 3           1     1      181.00   5828262         181.00            0.00
# 4           1     3    11668.14   3445981       41554.00        29885.86
# ...       ...   ...         ...       ...            ...             ...
# 6362615   743     1   339682.13   5651847      339682.13            0.00
# 6362616   743     4  6311409.28   1737278     6311409.28            0.00
# 6362617   743     1  6311409.28    533958     6311409.28            0.00
# 6362618   743     4   850002.52   2252932      850002.52            0.00
# 6362619   743     1   850002.52    919229      850002.52            0.00
#
#          nameDest  oldbalanceDest  newbalanceDest  isFlaggedFraud
# ...

# %%
y
# Out:
# 0          0
# 1          0
# 2          1
# 3          1
# 4          0
#           ..
# 6362615    1
# 6362616    1
# 6362617    1
# 6362618    1
# 6362619    1
# Name: isFraud, Length: 6362620, dtype: int64

# %%
# now split the data X_train,y_train
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y , random_state =3, test_size = 0.3)

# %%
X_train
# Out:
#          step  type     amount  nameOrig  oldbalanceOrg  newbalanceOrig  \
# 4489681   324     1     247.52   3903576           0.00            0.00
# 4977720   352     0  279716.00    120348       14662.00       294378.00
# 2522846   205     1   65084.94   3599568      504524.00       439439.06
# 2964892   231     0   13121.46    337168     6134953.09      6148074.54
# 3952872   287     3   22165.26    912102           0.00            0.00
# ...       ...   ...        ...       ...            ...             ...
# 1008584    46     1  318868.46   3438371       29700.95            0.00
# 452227     19     1   52630.35   1790171           0.00            0.00
# 4795641   345     3   36453.21   6286068         449.24            0.00
# 1771160   162     0  457566.27   5945376     2119602.13      2577168.40
# 71530       9     4  738886.28   1873733           0.00            0.00
#
#          nameDest  oldbalanceDest  newbalanceDest  isFlaggedFraud
# ...

# %%
 X_test
# Out:
#          step  type     amount  nameOrig  oldbalanceOrg  newbalanceOrig  \
# 1605953   156     0  165069.05   3890456     4646166.16      4811235.21
# 362350     17     1  255335.25   3798911       72400.00            0.00
# 870147     42     3    2672.27   3687605      120676.58       118004.31
# 429440     18     3   11100.20   4607940     1196367.32      1185267.13
# 523247     20     0   39524.17   4280482     2667967.73      2707491.90
# ...       ...   ...        ...       ...            ...             ...
# 5107639   355     3     359.49   2778812       21299.00        20939.51
# 4493296   325     3    9157.89   3477915         625.00            0.00
# 1537266   154     3    1634.61   5421719       26581.00        24946.39
# 4591552   328     1   22723.78   2240778           0.00            0.00
# 5499374   380     3    1350.81   4736123      269574.00       268223.19
#
#          nameDest  oldbalanceDest  newbalanceDest  isFlaggedFraud
# ...

# %%
y_train
# Out:
# 4489681    0
# 4977720    0
# 2522846    0
# 2964892    0
# 3952872    0
#           ..
# 1008584    0
# 452227     0
# 4795641    0
# 1771160    0
# 71530      0
# Name: isFraud, Length: 4453834, dtype: int64

# %%
y_test
# Out:
# 1605953    0
# 362350     0
# 870147     0
# 429440     0
# 523247     0
#           ..
# 5107639    0
# 4493296    0
# 1537266    0
# 4591552    0
# 5499374    0
# Name: isFraud, Length: 1908786, dtype: int64

# %%
# now we create the model  and check the accuracy
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import classification_report, f1_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score , plot_roc_curve
from sklearn.ensemble import GradientBoostingClassifier, StackingClassifier



gb = GradientBoostingClassifier()
model=gb
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

f1score = metrics.f1_score(y_test, y_pred).round(3)
accuracy = metrics.classification_report(y_test, y_pred)

# %%
##Results
print(accuracy,"\n")
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   1906331
#            1       0.84      0.62      0.71      2455
#
#     accuracy                           1.00   1908786
#    macro avg       0.92      0.81      0.86   1908786
# weighted avg       1.00      1.00      1.00   1908786

# %%
f1score
# Out:
# 0.711
